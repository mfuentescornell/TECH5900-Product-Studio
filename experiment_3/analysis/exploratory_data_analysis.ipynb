# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# #

# %%
df = pd.read_csv('../data/New_York_NY.csv')
df.head()
# Out:
# /var/folders/pv/0tf02fqx1292h57zvcs1ll300000gn/T/ipykernel_71428/847196654.py:1: DtypeWarning: Columns (3,9,15,18,30,36,38,44,45,57,58,78,86,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/New_York_NY.csv')
#   FILEID STUSAB  SUMLEV GEOVAR  GEOCOMP  CHARITER  CIFSN_x  LOGRECNO  \
# 0   PLST     NY      50      0        0         0        0         2
# 1   PLST     NY      50      0        0         0        0         3
# 2   PLST     NY      50      0        0         0        0         4
# 3   PLST     NY      50      0        0         0        0         5
# 4   PLST     NY      50      0        0         0        0         6
#
#             GEOID GEOCODE  ...  P0050001  P0050002  P0050003  P0050004  \
# 0  0500000US36001   36001  ...     16723      2716       303       186
# 1  0500000US36003   36003  ...      4502       544        78         0
# 2  0500000US36005   36005  ...     52815     15036      3815       272
# ...

# %%
df.describe()
# Out:
#               SUMLEV   GEOCOMP  CHARITER   CIFSN_x       LOGRECNO    REGION  \
# count  573373.000000  573373.0  573373.0  573373.0  573373.000000  573373.0
# mean      697.133159       0.0       0.0       0.0  286688.000000       1.0
# std       126.902233       0.0       0.0       0.0  165518.672286       0.0
# min        50.000000       0.0       0.0       0.0       2.000000       1.0
# 25%       707.000000       0.0       0.0       0.0  143345.000000       1.0
# 50%       750.000000       0.0       0.0       0.0  286688.000000       1.0
# 75%       750.000000       0.0       0.0       0.0  430031.000000       1.0
# max       970.000000       0.0       0.0       0.0  573374.000000       1.0
#
#        DIVISION     STATE    STATENS         COUNTY  ...       P0050001  \
# count  573373.0  573373.0   573373.0  558522.000000  ...  573373.000000
# mean        2.0      36.0  1779796.0      63.241828  ...      54.380557
# ...
